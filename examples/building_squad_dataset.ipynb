# %% [markdown]
# # Set up

# %%
# !pip install uv
# !pip install python-dotenv
# !pip install openai
# !pip install datasets
# !pip install evaluate
# !pip install tenacity

# %%
# !git clone https://github.com/leap-laboratories/PIZZA.git
# Out:
# Cloning into 'PIZZA'...
# remote: Enumerating objects: 1087, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 1087 (delta 63), reused 46 (delta 44), pack-reused 980 (from 1)
# Receiving objects: 100% (1087/1087), 4.59 MiB | 20.98 MiB/s, done.
# Resolving deltas: 100% (747/747), done.

# %%
# !git clone https://github.com/huggingface/evaluate.git
# Out:
# Cloning into 'evaluate'...
# remote: Enumerating objects: 8477, done.
# remote: Counting objects: 100% (887/887), done.
# remote: Compressing objects: 100% (201/201), done.
# remote: Total 8477 (delta 719), reused 732 (delta 677), pack-reused 7590 (from 1)
# Receiving objects: 100% (8477/8477), 2.22 MiB | 13.39 MiB/s, done.
# Resolving deltas: 100% (5166/5166), done.

# %%
# %cd PIZZA
# !uv venv
# !source .venv/bin/activate
# !uv pip install -r requirements.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# openai     ------------------------------ 160.00 KiB/285.99 KiB
# joblib     ------------------------------ 260.70 KiB/294.74 KiB
# fsspec     ------------------------------ 269.54 KiB/308.70 KiB
# tzdata     ------------------------------ 94.04 KiB/337.28 KiB
# huggingface-hub ------------------------------ 350.73 KiB/392.30 KiB
# pydantic   ------------------------------ 397.65 KiB/399.95 KiB
# pytz       ------------------------------ 109.62 KiB/493.63 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 575.38 KiB/804.29 KiB
# safetensors ------------------------------ 813.11 KiB/1.15 MiB
# pygments   ------------------------------ 495.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 846.52 KiB/1.54 MiB
# networkx   ------------------------------ 301.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 844.94 KiB/1.93 MiB
# tokenizers ------------------------------ 776.56 KiB/3.44 MiB
# pillow     ------------------------------ 832.00 KiB/4.29 MiB
# fonttools  ------------------------------ 333.19 KiB/4.41 MiB
# sympy      ------------------------------ 222.80 KiB/5.48 MiB
# matplotlib ------------------------------ 784.78 KiB/7.91 MiB
# transformers ------------------------------ 679.58 KiB/8.98 MiB
# scikit-learn ------------------------------ 818.95 KiB/11.58 MiB
# pandas     ------------------------------ 443.16 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 844.04 KiB/13.46 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 160.00 KiB/285.99 KiB
# joblib     ------------------------------ 260.70 KiB/294.74 KiB
# fsspec     ------------------------------ 269.54 KiB/308.70 KiB
# tzdata     ------------------------------ 94.04 KiB/337.28 KiB
# huggingface-hub ------------------------------ 350.73 KiB/392.30 KiB
# pytz       ------------------------------ 109.62 KiB/493.63 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 591.38 KiB/804.29 KiB
# safetensors ------------------------------ 813.11 KiB/1.15 MiB
# pygments   ------------------------------ 495.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 846.52 KiB/1.54 MiB
# networkx   ------------------------------ 301.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 844.94 KiB/1.93 MiB
# tokenizers ------------------------------ 776.56 KiB/3.44 MiB
# pillow     ------------------------------ 832.00 KiB/4.29 MiB
# fonttools  ------------------------------ 333.19 KiB/4.41 MiB
# sympy      ------------------------------ 222.80 KiB/5.48 MiB
# matplotlib ------------------------------ 784.78 KiB/7.91 MiB
# transformers ------------------------------ 679.58 KiB/8.98 MiB
# scikit-learn ------------------------------ 818.95 KiB/11.58 MiB
# pandas     ------------------------------ 443.16 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 844.04 KiB/13.46 MiB
# numpy      ------------------------------ 444.80 KiB/17.40 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 175.89 KiB/285.99 KiB
# joblib     ------------------------------ 270.88 KiB/294.74 KiB
# fsspec     ------------------------------ 294.29 KiB/308.70 KiB
# tzdata     ------------------------------ 94.04 KiB/337.28 KiB
# huggingface-hub ------------------------------ 366.73 KiB/392.30 KiB
# pytz       ------------------------------ 125.51 KiB/493.63 KiB
# safetensors ------------------------------ 850.30 KiB/1.15 MiB
# pygments   ------------------------------ 527.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 894.52 KiB/1.54 MiB
# networkx   ------------------------------ 317.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 892.94 KiB/1.93 MiB
# tokenizers ------------------------------ 824.56 KiB/3.44 MiB
# pillow     ------------------------------ 864.00 KiB/4.29 MiB
# fonttools  ------------------------------ 352.10 KiB/4.41 MiB
# sympy      ------------------------------ 254.80 KiB/5.48 MiB
# matplotlib ------------------------------ 816.00 KiB/7.91 MiB
# transformers ------------------------------ 727.58 KiB/8.98 MiB
# scikit-learn ------------------------------ 862.07 KiB/11.58 MiB
# pandas     ------------------------------ 462.78 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 876.26 KiB/13.46 MiB
# numpy      ------------------------------ 476.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 799.00 KiB/18.83 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 175.89 KiB/285.99 KiB
# joblib     ------------------------------ 270.88 KiB/294.74 KiB
# fsspec     ------------------------------ 303.51 KiB/308.70 KiB
# tzdata     ------------------------------ 94.04 KiB/337.28 KiB
# pytz       ------------------------------ 125.51 KiB/493.63 KiB
# safetensors ------------------------------ 898.30 KiB/1.15 MiB
# pygments   ------------------------------ 559.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 942.52 KiB/1.54 MiB
# networkx   ------------------------------ 333.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 937.32 KiB/1.93 MiB
# tokenizers ------------------------------ 872.56 KiB/3.44 MiB
# pillow     ------------------------------ 912.00 KiB/4.29 MiB
# fonttools  ------------------------------ 358.41 KiB/4.41 MiB
# sympy      ------------------------------ 286.91 KiB/5.48 MiB
# matplotlib ------------------------------ 864.00 KiB/7.91 MiB
# transformers ------------------------------ 772.34 KiB/8.98 MiB
# scikit-learn ------------------------------ 910.07 KiB/11.58 MiB
# pandas     ------------------------------ 515.00 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 924.26 KiB/13.46 MiB
# numpy      ------------------------------ 476.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 847.00 KiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 895.15 KiB/22.58 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 175.89 KiB/285.99 KiB
# joblib     ------------------------------ 270.88 KiB/294.74 KiB
# fsspec     ------------------------------ 303.51 KiB/308.70 KiB
# tzdata     ------------------------------ 94.04 KiB/337.28 KiB
# pytz       ------------------------------ 125.51 KiB/493.63 KiB
# safetensors ------------------------------ 898.30 KiB/1.15 MiB
# pygments   ------------------------------ 559.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 974.52 KiB/1.54 MiB
# networkx   ------------------------------ 333.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 937.32 KiB/1.93 MiB
# tokenizers ------------------------------ 904.56 KiB/3.44 MiB
# pillow     ------------------------------ 912.00 KiB/4.29 MiB
# fonttools  ------------------------------ 358.41 KiB/4.41 MiB
# sympy      ------------------------------ 286.91 KiB/5.48 MiB
# matplotlib ------------------------------ 864.00 KiB/7.91 MiB
# transformers ------------------------------ 772.34 KiB/8.98 MiB
# scikit-learn ------------------------------ 910.07 KiB/11.58 MiB
# pandas     ------------------------------ 515.00 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 924.26 KiB/13.46 MiB
# numpy      ------------------------------ 476.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 847.00 KiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 895.15 KiB/22.58 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 175.89 KiB/285.99 KiB
# joblib     ------------------------------ 270.88 KiB/294.74 KiB
# tzdata     ------------------------------ 94.04 KiB/337.28 KiB
# pytz       ------------------------------ 125.51 KiB/493.63 KiB
# safetensors ------------------------------ 909.11 KiB/1.15 MiB
# pygments   ------------------------------ 559.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 974.52 KiB/1.54 MiB
# networkx   ------------------------------ 333.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 960.98 KiB/1.93 MiB
# tokenizers ------------------------------ 904.56 KiB/3.44 MiB
# pillow     ------------------------------ 928.00 KiB/4.29 MiB
# fonttools  ------------------------------ 358.41 KiB/4.41 MiB
# sympy      ------------------------------ 318.91 KiB/5.48 MiB
# matplotlib ------------------------------ 880.00 KiB/7.91 MiB
# transformers ------------------------------ 772.34 KiB/8.98 MiB
# scikit-learn ------------------------------ 926.07 KiB/11.58 MiB
# pandas     ------------------------------ 515.00 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 929.33 KiB/13.46 MiB
# numpy      ------------------------------ 476.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 863.00 KiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 911.15 KiB/22.58 MiB
# scipy      ------------------------------ 894.07 KiB/36.79 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 191.89 KiB/285.99 KiB
# joblib     ------------------------------ 286.88 KiB/294.74 KiB
# tzdata     ------------------------------ 110.04 KiB/337.28 KiB
# pytz       ------------------------------ 142.86 KiB/493.63 KiB
# safetensors ------------------------------ 1005.11 KiB/1.15 MiB
# pygments   ------------------------------ 652.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 1.06 MiB/1.54 MiB
# networkx   ------------------------------ 381.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.01 MiB/1.93 MiB
# tokenizers ------------------------------ 995.56 KiB/3.44 MiB
# pillow     ------------------------------ 1023.89 KiB/4.29 MiB
# fonttools  ------------------------------ 429.19 KiB/4.41 MiB
# sympy      ------------------------------ 408.56 KiB/5.48 MiB
# matplotlib ------------------------------ 992.00 KiB/7.91 MiB
# transformers ------------------------------ 951.58 KiB/8.98 MiB
# scikit-learn ------------------------------ 1022.07 KiB/11.58 MiB
# pandas     ------------------------------ 734.78 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1020.26 KiB/13.46 MiB
# numpy      ------------------------------ 588.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 959.00 KiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1007.15 KiB/22.58 MiB
# scipy      ------------------------------ 974.07 KiB/36.79 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 191.89 KiB/285.99 KiB
# tzdata     ------------------------------ 110.04 KiB/337.28 KiB
# pytz       ------------------------------ 142.86 KiB/493.63 KiB
# safetensors ------------------------------ 1.03 MiB/1.15 MiB
# pygments   ------------------------------ 652.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 1.08 MiB/1.54 MiB
# networkx   ------------------------------ 381.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.06 MiB/1.93 MiB
# tokenizers ------------------------------ 1.02 MiB/3.44 MiB
# pillow     ------------------------------ 1.03 MiB/4.29 MiB
# fonttools  ------------------------------ 511.64 KiB/4.41 MiB
# sympy      ------------------------------ 408.56 KiB/5.48 MiB
# matplotlib ------------------------------ 1.02 MiB/7.91 MiB
# transformers ------------------------------ 951.58 KiB/8.98 MiB
# scikit-learn ------------------------------ 1.03 MiB/11.58 MiB
# pandas     ------------------------------ 734.78 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.03 MiB/13.46 MiB
# numpy      ------------------------------ 588.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1001.36 KiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.03 MiB/22.58 MiB
# scipy      ------------------------------ 1006.17 KiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1021.94 KiB/53.85 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 191.89 KiB/285.99 KiB
# tzdata     ------------------------------ 110.04 KiB/337.28 KiB
# pytz       ------------------------------ 158.75 KiB/493.63 KiB
# safetensors ------------------------------ 1.08 MiB/1.15 MiB
# pygments   ------------------------------ 767.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 1.12 MiB/1.54 MiB
# networkx   ------------------------------ 413.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.09 MiB/1.93 MiB
# tokenizers ------------------------------ 1.07 MiB/3.44 MiB
# pillow     ------------------------------ 1.06 MiB/4.29 MiB
# fonttools  ------------------------------ 1021.19 KiB/4.41 MiB
# sympy      ------------------------------ 456.34 KiB/5.48 MiB
# matplotlib ------------------------------ 1.06 MiB/7.91 MiB
# transformers ------------------------------ 983.58 KiB/8.98 MiB
# scikit-learn ------------------------------ 1.06 MiB/11.58 MiB
# pandas     ------------------------------ 974.78 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.06 MiB/13.46 MiB
# numpy      ------------------------------ 604.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1007.00 KiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.06 MiB/22.58 MiB
# scipy      ------------------------------ 1.03 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.04 MiB/53.85 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 191.89 KiB/285.99 KiB
# tzdata     ------------------------------ 110.04 KiB/337.28 KiB
# pytz       ------------------------------ 158.75 KiB/493.63 KiB
# pygments   ------------------------------ 831.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 1.20 MiB/1.54 MiB
# networkx   ------------------------------ 429.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.18 MiB/1.93 MiB
# tokenizers ------------------------------ 1.13 MiB/3.44 MiB
# pillow     ------------------------------ 1.14 MiB/4.29 MiB
# fonttools  ------------------------------ 1.01 MiB/4.41 MiB
# sympy      ------------------------------ 504.56 KiB/5.48 MiB
# matplotlib ------------------------------ 1.14 MiB/7.91 MiB
# transformers ------------------------------ 983.58 KiB/8.98 MiB
# scikit-learn ------------------------------ 1.15 MiB/11.58 MiB
# pandas     ------------------------------ 1022.67 KiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.15 MiB/13.46 MiB
# numpy      ------------------------------ 620.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.06 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.12 MiB/22.58 MiB
# scipy      ------------------------------ 1.09 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.10 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.12 MiB/116.00 MiB
# ⠴ Preparing packages... (32/68)
# openai     ------------------------------ 208.00 KiB/285.99 KiB
# tzdata     ------------------------------ 126.04 KiB/337.28 KiB
# pytz       ------------------------------ 158.75 KiB/493.63 KiB
# pygments   ------------------------------ 847.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 1.23 MiB/1.54 MiB
# networkx   ------------------------------ 445.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.23 MiB/1.93 MiB
# tokenizers ------------------------------ 1.19 MiB/3.44 MiB
# pillow     ------------------------------ 1.19 MiB/4.29 MiB
# fonttools  ------------------------------ 1.15 MiB/4.41 MiB
# sympy      ------------------------------ 584.56 KiB/5.48 MiB
# matplotlib ------------------------------ 1.19 MiB/7.91 MiB
# transformers ------------------------------ 999.58 KiB/8.98 MiB
# scikit-learn ------------------------------ 1.22 MiB/11.58 MiB
# pandas     ------------------------------ 1.08 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.20 MiB/13.46 MiB
# numpy      ------------------------------ 620.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.10 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.18 MiB/22.58 MiB
# scipy      ------------------------------ 1.15 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.16 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.18 MiB/116.00 MiB
# ⠦ Preparing packages... (39/68)
# openai     ------------------------------ 224.00 KiB/285.99 KiB
# tzdata     ------------------------------ 126.04 KiB/337.28 KiB
# pytz       ------------------------------ 174.75 KiB/493.63 KiB
# pygments   ------------------------------ 910.87 KiB/1.15 MiB
# kiwisolver ------------------------------ 1.39 MiB/1.54 MiB
# networkx   ------------------------------ 477.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.39 MiB/1.93 MiB
# tokenizers ------------------------------ 1.36 MiB/3.44 MiB
# pillow     ------------------------------ 1.36 MiB/4.29 MiB
# fonttools  ------------------------------ 1.29 MiB/4.41 MiB
# sympy      ------------------------------ 744.46 KiB/5.48 MiB
# matplotlib ------------------------------ 1.32 MiB/7.91 MiB
# transformers ------------------------------ 1.06 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.36 MiB/11.58 MiB
# pandas     ------------------------------ 1.23 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.37 MiB/13.46 MiB
# numpy      ------------------------------ 620.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.26 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.32 MiB/22.58 MiB
# scipy      ------------------------------ 1.31 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.31 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.30 MiB/116.00 MiB
# ⠦ Preparing packages... (39/68)
# openai     ------------------------------ 224.00 KiB/285.99 KiB
# tzdata     ------------------------------ 142.04 KiB/337.28 KiB
# pytz       ------------------------------ 190.75 KiB/493.63 KiB
# pygments   ------------------------------ 991.08 KiB/1.15 MiB
# kiwisolver ------------------------------ 1.51 MiB/1.54 MiB
# networkx   ------------------------------ 525.13 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.51 MiB/1.93 MiB
# tokenizers ------------------------------ 1.46 MiB/3.44 MiB
# pillow     ------------------------------ 1.46 MiB/4.29 MiB
# fonttools  ------------------------------ 1.42 MiB/4.41 MiB
# sympy      ------------------------------ 840.56 KiB/5.48 MiB
# matplotlib ------------------------------ 1.44 MiB/7.91 MiB
# transformers ------------------------------ 1.18 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.47 MiB/11.58 MiB
# pandas     ------------------------------ 1.37 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.48 MiB/13.46 MiB
# numpy      ------------------------------ 636.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.38 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.45 MiB/22.58 MiB
# scipy      ------------------------------ 1.42 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.45 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.42 MiB/116.00 MiB
# ⠦ Preparing packages... (39/68)
# openai     ------------------------------ 240.00 KiB/285.99 KiB
# tzdata     ------------------------------ 142.04 KiB/337.28 KiB
# pytz       ------------------------------ 206.86 KiB/493.63 KiB
# pygments   ------------------------------ 1007.08 KiB/1.15 MiB
# networkx   ------------------------------ 557.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.56 MiB/1.93 MiB
# tokenizers ------------------------------ 1.49 MiB/3.44 MiB
# pillow     ------------------------------ 1.50 MiB/4.29 MiB
# fonttools  ------------------------------ 1.47 MiB/4.41 MiB
# sympy      ------------------------------ 881.70 KiB/5.48 MiB
# matplotlib ------------------------------ 1.48 MiB/7.91 MiB
# transformers ------------------------------ 1.24 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.50 MiB/11.58 MiB
# pandas     ------------------------------ 1.43 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.51 MiB/13.46 MiB
# numpy      ------------------------------ 652.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.43 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.49 MiB/22.58 MiB
# scipy      ------------------------------ 1.47 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.48 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.46 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.54 MiB/118.41 MiB
# ⠦ Preparing packages... (39/68)
# openai     ------------------------------ 240.00 KiB/285.99 KiB
# tzdata     ------------------------------ 158.04 KiB/337.28 KiB
# pytz       ------------------------------ 222.86 KiB/493.63 KiB
# pygments   ------------------------------ 1.04 MiB/1.15 MiB
# networkx   ------------------------------ 693.57 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.65 MiB/1.93 MiB
# tokenizers ------------------------------ 1.56 MiB/3.44 MiB
# pillow     ------------------------------ 1.59 MiB/4.29 MiB
# fonttools  ------------------------------ 1.58 MiB/4.41 MiB
# sympy      ------------------------------ 979.56 KiB/5.48 MiB
# matplotlib ------------------------------ 1.58 MiB/7.91 MiB
# transformers ------------------------------ 1.32 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.59 MiB/11.58 MiB
# pandas     ------------------------------ 1.51 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.59 MiB/13.46 MiB
# numpy      ------------------------------ 668.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.51 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.59 MiB/22.58 MiB
# scipy      ------------------------------ 1.55 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.54 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.57 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.63 MiB/118.41 MiB
# ⠦ Preparing packages... (39/68)
# tzdata     ------------------------------ 158.04 KiB/337.28 KiB
# pytz       ------------------------------ 238.86 KiB/493.63 KiB
# pygments   ------------------------------ 1.07 MiB/1.15 MiB
# networkx   ------------------------------ 829.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.74 MiB/1.93 MiB
# tokenizers ------------------------------ 1.66 MiB/3.44 MiB
# pillow     ------------------------------ 1.67 MiB/4.29 MiB
# fonttools  ------------------------------ 1.66 MiB/4.41 MiB
# sympy      ------------------------------ 1011.56 KiB/5.48 MiB
# matplotlib ------------------------------ 1.66 MiB/7.91 MiB
# transformers ------------------------------ 1.38 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.65 MiB/11.58 MiB
# pandas     ------------------------------ 1.54 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.65 MiB/13.46 MiB
# numpy      ------------------------------ 684.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.59 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.67 MiB/22.58 MiB
# scipy      ------------------------------ 1.64 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.64 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.63 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.68 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 1.69 MiB/158.30 MiB
# ⠦ Preparing packages... (39/68)
# tzdata     ------------------------------ 158.04 KiB/337.28 KiB
# pytz       ------------------------------ 238.86 KiB/493.63 KiB
# pygments   ------------------------------ 1.08 MiB/1.15 MiB
# networkx   ------------------------------ 845.23 KiB/1.62 MiB
# pydantic-core ------------------------------ 1.82 MiB/1.93 MiB
# tokenizers ------------------------------ 1.72 MiB/3.44 MiB
# pillow     ------------------------------ 1.73 MiB/4.29 MiB
# fonttools  ------------------------------ 1.73 MiB/4.41 MiB
# sympy      ------------------------------ 1.00 MiB/5.48 MiB
# matplotlib ------------------------------ 1.72 MiB/7.91 MiB
# transformers ------------------------------ 1.46 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.72 MiB/11.58 MiB
# pandas     ------------------------------ 1.67 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.74 MiB/13.46 MiB
# numpy      ------------------------------ 684.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.65 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.73 MiB/22.58 MiB
# scipy      ------------------------------ 1.70 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.70 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.71 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.76 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 1.76 MiB/158.30 MiB
# ⠧ Preparing packages... (41/68)
# tzdata     ------------------------------ 174.04 KiB/337.28 KiB
# pytz       ------------------------------ 254.86 KiB/493.63 KiB
# pygments   ------------------------------ 1.11 MiB/1.15 MiB
# networkx   ------------------------------ 909.23 KiB/1.62 MiB
# tokenizers ------------------------------ 1.85 MiB/3.44 MiB
# pillow     ------------------------------ 1.86 MiB/4.29 MiB
# fonttools  ------------------------------ 1.83 MiB/4.41 MiB
# sympy      ------------------------------ 1.13 MiB/5.48 MiB
# matplotlib ------------------------------ 1.81 MiB/7.91 MiB
# transformers ------------------------------ 1.57 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.83 MiB/11.58 MiB
# pandas     ------------------------------ 1.73 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.84 MiB/13.46 MiB
# numpy      ------------------------------ 748.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.78 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.82 MiB/22.58 MiB
# scipy      ------------------------------ 1.80 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.81 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.85 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.89 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 1.86 MiB/158.30 MiB
# triton     ------------------------------ 1.87 MiB/160.12 MiB
# ⠧ Preparing packages... (41/68)
# tzdata     ------------------------------ 174.04 KiB/337.28 KiB
# pytz       ------------------------------ 254.86 KiB/493.63 KiB
# pygments   ------------------------------ 1.11 MiB/1.15 MiB
# networkx   ------------------------------ 909.23 KiB/1.62 MiB
# tokenizers ------------------------------ 1.86 MiB/3.44 MiB
# pillow     ------------------------------ 1.88 MiB/4.29 MiB
# fonttools  ------------------------------ 1.86 MiB/4.41 MiB
# sympy      ------------------------------ 1.14 MiB/5.48 MiB
# matplotlib ------------------------------ 1.83 MiB/7.91 MiB
# transformers ------------------------------ 1.59 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.84 MiB/11.58 MiB
# pandas     ------------------------------ 1.73 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.84 MiB/13.46 MiB
# numpy      ------------------------------ 764.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.79 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.85 MiB/22.58 MiB
# scipy      ------------------------------ 1.81 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.84 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.87 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.90 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 1.87 MiB/158.30 MiB
# triton     ------------------------------ 1.88 MiB/160.12 MiB
# ⠧ Preparing packages... (41/68)
# tzdata     ------------------------------ 190.04 KiB/337.28 KiB
# pytz       ------------------------------ 270.75 KiB/493.63 KiB
# networkx   ------------------------------ 925.23 KiB/1.62 MiB
# tokenizers ------------------------------ 1.95 MiB/3.44 MiB
# pillow     ------------------------------ 1.97 MiB/4.29 MiB
# fonttools  ------------------------------ 1.93 MiB/4.41 MiB
# sympy      ------------------------------ 1.24 MiB/5.48 MiB
# matplotlib ------------------------------ 1.93 MiB/7.91 MiB
# transformers ------------------------------ 1.66 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.94 MiB/11.58 MiB
# pandas     ------------------------------ 1.73 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.93 MiB/13.46 MiB
# numpy      ------------------------------ 828.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.88 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.93 MiB/22.58 MiB
# scipy      ------------------------------ 1.89 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.93 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 1.98 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.00 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 1.97 MiB/158.30 MiB
# triton     ------------------------------ 1.97 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.98 MiB/186.88 MiB
# ⠧ Preparing packages... (41/68)
# tzdata     ------------------------------ 190.04 KiB/337.28 KiB
# pytz       ------------------------------ 270.75 KiB/493.63 KiB
# networkx   ------------------------------ 957.23 KiB/1.62 MiB
# tokenizers ------------------------------ 2.01 MiB/3.44 MiB
# pillow     ------------------------------ 2.00 MiB/4.29 MiB
# fonttools  ------------------------------ 1.98 MiB/4.41 MiB
# sympy      ------------------------------ 1.27 MiB/5.48 MiB
# matplotlib ------------------------------ 1.97 MiB/7.91 MiB
# transformers ------------------------------ 1.73 MiB/8.98 MiB
# scikit-learn ------------------------------ 1.97 MiB/11.58 MiB
# pandas     ------------------------------ 1.77 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.98 MiB/13.46 MiB
# numpy      ------------------------------ 844.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.93 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.96 MiB/22.58 MiB
# scipy      ------------------------------ 1.93 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 1.96 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 2.01 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.04 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 2.03 MiB/158.30 MiB
# triton     ------------------------------ 2.00 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.03 MiB/186.88 MiB
# ⠧ Preparing packages... (41/68)
# tzdata     ------------------------------ 206.04 KiB/337.28 KiB
# pytz       ------------------------------ 286.86 KiB/493.63 KiB
# networkx   ------------------------------ 1021.23 KiB/1.62 MiB
# tokenizers ------------------------------ 2.04 MiB/3.44 MiB
# pillow     ------------------------------ 2.06 MiB/4.29 MiB
# fonttools  ------------------------------ 2.03 MiB/4.41 MiB
# sympy      ------------------------------ 1.46 MiB/5.48 MiB
# matplotlib ------------------------------ 2.03 MiB/7.91 MiB
# transformers ------------------------------ 1.90 MiB/8.98 MiB
# scikit-learn ------------------------------ 2.03 MiB/11.58 MiB
# pandas     ------------------------------ 1.88 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.04 MiB/13.46 MiB
# numpy      ------------------------------ 988.70 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.99 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.99 MiB/22.58 MiB
# scipy      ------------------------------ 1.98 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 2.03 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 2.08 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.10 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 2.08 MiB/158.30 MiB
# triton     ------------------------------ 2.05 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.07 MiB/186.88 MiB
# ⠧ Preparing packages... (41/68)
# tzdata     ------------------------------ 222.04 KiB/337.28 KiB
# pytz       ------------------------------ 318.86 KiB/493.63 KiB
# networkx   ------------------------------ 1.15 MiB/1.62 MiB
# tokenizers ------------------------------ 2.20 MiB/3.44 MiB
# pillow     ------------------------------ 2.20 MiB/4.29 MiB
# fonttools  ------------------------------ 2.11 MiB/4.41 MiB
# sympy      ------------------------------ 1.66 MiB/5.48 MiB
# matplotlib ------------------------------ 2.17 MiB/7.91 MiB
# transformers ------------------------------ 2.10 MiB/8.98 MiB
# scikit-learn ------------------------------ 2.17 MiB/11.58 MiB
# pandas     ------------------------------ 1.92 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.15 MiB/13.46 MiB
# numpy      ------------------------------ 1020.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.13 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.13 MiB/22.58 MiB
# scipy      ------------------------------ 2.13 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 2.16 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 2.22 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.21 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 2.23 MiB/158.30 MiB
# triton     ------------------------------ 2.20 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.23 MiB/186.88 MiB
# ⠇ Preparing packages... (43/68)
# tzdata     ------------------------------ 222.04 KiB/337.28 KiB
# pytz       ------------------------------ 334.86 KiB/493.63 KiB
# networkx   ------------------------------ 1.22 MiB/1.62 MiB
# tokenizers ------------------------------ 2.37 MiB/3.44 MiB
# pillow     ------------------------------ 2.37 MiB/4.29 MiB
# fonttools  ------------------------------ 2.14 MiB/4.41 MiB
# sympy      ------------------------------ 1.67 MiB/5.48 MiB
# matplotlib ------------------------------ 2.23 MiB/7.91 MiB
# transformers ------------------------------ 2.16 MiB/8.98 MiB
# scikit-learn ------------------------------ 2.34 MiB/11.58 MiB
# pandas     ------------------------------ 1.95 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.30 MiB/13.46 MiB
# numpy      ------------------------------ 1020.80 KiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.30 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.32 MiB/22.58 MiB
# scipy      ------------------------------ 2.23 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 2.35 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 2.38 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.38 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 2.40 MiB/158.30 MiB
# triton     ------------------------------ 2.36 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.38 MiB/186.88 MiB
# ⠇ Preparing packages... (43/68)
# tzdata     ------------------------------ 222.04 KiB/337.28 KiB
# pytz       ------------------------------ 334.86 KiB/493.63 KiB
# networkx   ------------------------------ 1.33 MiB/1.62 MiB
# tokenizers ------------------------------ 2.51 MiB/3.44 MiB
# pillow     ------------------------------ 2.50 MiB/4.29 MiB
# fonttools  ------------------------------ 2.49 MiB/4.41 MiB
# sympy      ------------------------------ 1.78 MiB/5.48 MiB
# matplotlib ------------------------------ 2.47 MiB/7.91 MiB
# transformers ------------------------------ 2.26 MiB/8.98 MiB
# scikit-learn ------------------------------ 2.48 MiB/11.58 MiB
# pandas     ------------------------------ 2.01 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.44 MiB/13.46 MiB
# numpy      ------------------------------ 1.01 MiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.44 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.46 MiB/22.58 MiB
# scipy      ------------------------------ 2.42 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 2.51 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 2.52 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.52 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 2.56 MiB/158.30 MiB
# triton     ------------------------------ 2.51 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.51 MiB/186.88 MiB
# ⠇ Preparing packages... (43/68)
# tzdata     ------------------------------ 239.13 KiB/337.28 KiB
# pytz       ------------------------------ 382.86 KiB/493.63 KiB
# networkx   ------------------------------ 1.39 MiB/1.62 MiB
# tokenizers ------------------------------ 2.66 MiB/3.44 MiB
# pillow     ------------------------------ 2.67 MiB/4.29 MiB
# fonttools  ------------------------------ 2.61 MiB/4.41 MiB
# sympy      ------------------------------ 1.87 MiB/5.48 MiB
# matplotlib ------------------------------ 2.61 MiB/7.91 MiB
# transformers ------------------------------ 2.45 MiB/8.98 MiB
# scikit-learn ------------------------------ 2.64 MiB/11.58 MiB
# pandas     ------------------------------ 2.14 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.62 MiB/13.46 MiB
# numpy      ------------------------------ 1.14 MiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.59 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.63 MiB/22.58 MiB
# scipy      ------------------------------ 2.60 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 2.66 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 2.69 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.66 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 2.70 MiB/158.30 MiB
# triton     ------------------------------ 2.68 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.70 MiB/186.88 MiB
# ⠇ Preparing packages... (43/68)
# tzdata     ------------------------------ 254.04 KiB/337.28 KiB
# pytz       ------------------------------ 398.86 KiB/493.63 KiB
# networkx   ------------------------------ 1.45 MiB/1.62 MiB
# tokenizers ------------------------------ 2.79 MiB/3.44 MiB
# pillow     ------------------------------ 2.78 MiB/4.29 MiB
# fonttools  ------------------------------ 2.72 MiB/4.41 MiB
# sympy      ------------------------------ 1.91 MiB/5.48 MiB
# matplotlib ------------------------------ 2.72 MiB/7.91 MiB
# transformers ------------------------------ 2.59 MiB/8.98 MiB
# scikit-learn ------------------------------ 2.77 MiB/11.58 MiB
# pandas     ------------------------------ 2.20 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.75 MiB/13.46 MiB
# numpy      ------------------------------ 1.31 MiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.73 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.75 MiB/22.58 MiB
# scipy      ------------------------------ 2.73 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 2.80 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 2.82 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.77 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 2.83 MiB/158.30 MiB
# triton     ------------------------------ 2.80 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.84 MiB/186.88 MiB
# ⠋ Preparing packages... (43/68)
# tzdata     ------------------------------ 270.04 KiB/337.28 KiB
# pytz       ------------------------------ 414.86 KiB/493.63 KiB
# networkx   ------------------------------ 1.48 MiB/1.62 MiB
# tokenizers ------------------------------ 2.92 MiB/3.44 MiB
# pillow     ------------------------------ 2.89 MiB/4.29 MiB
# fonttools  ------------------------------ 2.86 MiB/4.41 MiB
# sympy      ------------------------------ 1.98 MiB/5.48 MiB
# matplotlib ------------------------------ 2.84 MiB/7.91 MiB
# transformers ------------------------------ 2.66 MiB/8.98 MiB
# scikit-learn ------------------------------ 2.90 MiB/11.58 MiB
# pandas     ------------------------------ 2.26 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.87 MiB/13.46 MiB
# numpy      ------------------------------ 2.18 MiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.88 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.88 MiB/22.58 MiB
# scipy      ------------------------------ 2.84 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 2.93 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 2.96 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.88 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 2.97 MiB/158.30 MiB
# triton     ------------------------------ 2.92 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.98 MiB/186.88 MiB
# ⠋ Preparing packages... (43/68)
# tzdata     ------------------------------ 270.04 KiB/337.28 KiB
# pytz       ------------------------------ 414.86 KiB/493.63 KiB
# networkx   ------------------------------ 1.56 MiB/1.62 MiB
# tokenizers ------------------------------ 3.10 MiB/3.44 MiB
# pillow     ------------------------------ 3.00 MiB/4.29 MiB
# fonttools  ------------------------------ 3.03 MiB/4.41 MiB
# sympy      ------------------------------ 2.06 MiB/5.48 MiB
# matplotlib ------------------------------ 3.03 MiB/7.91 MiB
# transformers ------------------------------ 2.77 MiB/8.98 MiB
# scikit-learn ------------------------------ 3.09 MiB/11.58 MiB
# pandas     ------------------------------ 2.32 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.05 MiB/13.46 MiB
# numpy      ------------------------------ 2.46 MiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.05 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.08 MiB/22.58 MiB
# scipy      ------------------------------ 3.06 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 3.09 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 3.10 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.06 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 3.16 MiB/158.30 MiB
# triton     ------------------------------ 3.13 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.14 MiB/186.88 MiB
# ⠋ Preparing packages... (43/68)
# tzdata     ------------------------------ 270.04 KiB/337.28 KiB
# pytz       ------------------------------ 414.86 KiB/493.63 KiB
# tokenizers ------------------------------ 3.14 MiB/3.44 MiB
# pillow     ------------------------------ 3.11 MiB/4.29 MiB
# fonttools  ------------------------------ 3.05 MiB/4.41 MiB
# sympy      ------------------------------ 2.07 MiB/5.48 MiB
# matplotlib ------------------------------ 3.08 MiB/7.91 MiB
# transformers ------------------------------ 2.80 MiB/8.98 MiB
# scikit-learn ------------------------------ 3.11 MiB/11.58 MiB
# pandas     ------------------------------ 2.35 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.08 MiB/13.46 MiB
# numpy      ------------------------------ 2.47 MiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.08 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.10 MiB/22.58 MiB
# scipy      ------------------------------ 3.08 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 3.12 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 3.11 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.11 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 3.18 MiB/158.30 MiB
# triton     ------------------------------ 3.15 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.17 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 2.97 MiB/391.57 MiB
# ⠋ Preparing packages... (43/68)
# tzdata     ------------------------------ 337.28 KiB/337.28 KiB
# tokenizers ------------------------------ 3.24 MiB/3.44 MiB
# pillow     ------------------------------ 3.16 MiB/4.29 MiB
# fonttools  ------------------------------ 3.15 MiB/4.41 MiB
# sympy      ------------------------------ 2.12 MiB/5.48 MiB
# matplotlib ------------------------------ 3.16 MiB/7.91 MiB
# transformers ------------------------------ 2.85 MiB/8.98 MiB
# scikit-learn ------------------------------ 3.21 MiB/11.58 MiB
# pandas     ------------------------------ 2.41 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.16 MiB/13.46 MiB
# numpy      ------------------------------ 2.54 MiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.19 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.22 MiB/22.58 MiB
# scipy      ------------------------------ 3.19 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 3.22 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 3.19 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.20 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 3.28 MiB/158.30 MiB
# triton     ------------------------------ 3.27 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.28 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 3.09 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 3.14 MiB/697.83 MiB
# ⠋ Preparing packages... (43/68)
# tokenizers ------------------------------ 3.24 MiB/3.44 MiB
# pillow     ------------------------------ 3.16 MiB/4.29 MiB
# fonttools  ------------------------------ 3.15 MiB/4.41 MiB
# sympy      ------------------------------ 2.12 MiB/5.48 MiB
# matplotlib ------------------------------ 3.16 MiB/7.91 MiB
# transformers ------------------------------ 2.85 MiB/8.98 MiB
# scikit-learn ------------------------------ 3.21 MiB/11.58 MiB
# pandas     ------------------------------ 2.41 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.16 MiB/13.46 MiB
# numpy      ------------------------------ 2.54 MiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.19 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.22 MiB/22.58 MiB
# scipy      ------------------------------ 3.19 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 3.22 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 3.19 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.20 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 3.28 MiB/158.30 MiB
# triton     ------------------------------ 3.27 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.28 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 3.09 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 3.14 MiB/697.83 MiB
# ⠋ Preparing packages... (43/68)
# tokenizers ------------------------------ 3.27 MiB/3.44 MiB
# pillow     ------------------------------ 3.25 MiB/4.29 MiB
# fonttools  ------------------------------ 3.16 MiB/4.41 MiB
# sympy      ------------------------------ 2.14 MiB/5.48 MiB
# matplotlib ------------------------------ 3.19 MiB/7.91 MiB
# transformers ------------------------------ 2.87 MiB/8.98 MiB
# scikit-learn ------------------------------ 3.25 MiB/11.58 MiB
# pandas     ------------------------------ 2.41 MiB/12.43 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.20 MiB/13.46 MiB
# numpy      ------------------------------ 2.56 MiB/17.40 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.24 MiB/18.83 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.24 MiB/22.58 MiB
# scipy      ------------------------------ 3.22 MiB/36.79 MiB
# nvidia-curand-cu12 ------------------------------ 3.25 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 3.22 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.24 MiB/118.41 MiB
# nvidia-nccl-cu12 ------------------------------ 3.31 MiB/158.30 MiB
# triton     ------------------------------ 3.30 MiB/160.12 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.33 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 3.11 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 3.16 MiB/697.83 MiB
# ⠋ Preparing packages... (43/68)
# tokenizers ------------------------------ 3.42 MiB/3.44 MiB
# ...
# ⠋ Preparing packages... (65/68)
# nvidia-cublas-cu12 ------------------------------ 385.08 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 394.26 MiB/697.83 MiB
# ⠋ Preparing packages... (65/68)
# nvidia-cublas-cu12 ------------------------------ 386.65 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 395.74 MiB/697.83 MiB
# ⠋ Preparing packages... (65/68)
# nvidia-cublas-cu12 ------------------------------ 388.34 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 397.59 MiB/697.83 MiB
# ⠋ Preparing packages... (65/68)
# nvidia-cublas-cu12 ------------------------------ 390.09 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 399.58 MiB/697.83 MiB
# ⠙ Preparing packages... (65/68)
# nvidia-cublas-cu12 ------------------------------ 391.30 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 401.31 MiB/697.83 MiB
# ⠙ Preparing packages... (65/68)
# nvidia-cublas-cu12 ------------------------------ 391.56 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 403.34 MiB/697.83 MiB
# ⠙ Preparing packages... (65/68)
# nvidia-cublas-cu12 ------------------------------ 391.57 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 406.08 MiB/697.83 MiB
# ⠙ Preparing packages... (65/68)
# nvidia-cublas-cu12 ------------------------------ 391.57 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 408.34 MiB/697.83 MiB
# ⠹ Preparing packages... (65/68)
# nvidia-cudnn-cu12 ------------------------------ 410.31 MiB/697.83 MiB
# ⠹ Preparing packages... (65/68)
# nvidia-cudnn-cu12 ------------------------------ 410.33 MiB/697.83 MiB
# ⠹ Preparing packages... (65/68)
# nvidia-cudnn-cu12 ------------------------------ 413.31 MiB/697.83 MiB
# ⠹ Preparing packages... (65/68)
# nvidia-cudnn-cu12 ------------------------------ 416.22 MiB/697.83 MiB
# ⠹ Preparing packages... (65/68)
# nvidia-cudnn-cu12 ------------------------------ 418.65 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 421.14 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 423.84 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 425.92 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 429.05 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 431.15 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 433.09 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 436.22 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 439.08 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 441.12 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 443.32 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 446.14 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 448.31 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 451.09 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 453.94 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 456.25 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 459.15 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 461.20 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 464.22 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 466.87 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 469.11 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 471.51 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 474.28 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 476.78 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 480.09 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 482.62 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 485.15 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 488.14 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 490.53 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 493.31 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 496.28 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 499.14 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 502.09 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 504.02 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 504.34 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 507.17 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 510.09 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 512.72 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 516.07 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 518.73 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 521.02 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 523.59 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 525.94 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 529.55 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 531.87 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 534.53 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 537.25 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 540.09 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 542.86 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 545.67 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 549.17 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 552.05 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 555.44 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 558.37 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 561.81 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 564.23 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 567.80 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 570.79 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 574.39 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 577.69 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 580.59 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 583.95 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 587.10 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 590.42 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 593.69 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 596.55 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 599.61 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 601.66 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 603.72 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 606.67 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 608.50 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 612.83 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 615.86 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 618.06 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 620.65 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 623.17 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 625.21 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 627.20 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 629.14 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 631.23 MiB/697.83 MiB
# ⠼ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 633.31 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 635.72 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 638.14 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 640.70 MiB/697.83 MiB
# ⠴ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 643.16 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 645.22 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 647.00 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 649.05 MiB/697.83 MiB
# ⠦ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 651.08 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 653.05 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 655.08 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 657.70 MiB/697.83 MiB
# ⠧ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 660.31 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 662.98 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 664.98 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 667.00 MiB/697.83 MiB
# ⠇ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 669.06 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 671.09 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 673.93 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 676.73 MiB/697.83 MiB
# ⠋ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 679.00 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 680.69 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 683.89 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 685.80 MiB/697.83 MiB
# ⠙ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 688.12 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 690.65 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 692.78 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 694.83 MiB/697.83 MiB
# ⠹ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 696.84 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# nvidia-cudnn-cu12 ------------------------------ 697.80 MiB/697.83 MiB
# ⠸ Preparing packages... (66/68)
# ⠸ Preparing packages... (66/68)
# ⠸ Preparing packages... (66/68)
# ⠸ Preparing packages... (66/68)
# ⠼ Preparing packages... (66/68)
# ⠼ Preparing packages... (66/68)
# ⠼ Preparing packages... (66/68)
# ⠼ Preparing packages... (66/68)
# ⠴ Preparing packages... (66/68)
# ⠴ Preparing packages... (66/68)
# ⠴ Preparing packages... (66/68)
# ⠴ Preparing packages... (66/68)
# ⠦ Preparing packages... (66/68)
# ⠦ Preparing packages... (66/68)
# ⠦ Preparing packages... (66/68)
# ⠦ Preparing packages... (66/68)
# ⠧ Preparing packages... (66/68)
# ⠧ Preparing packages... (66/68)
# ⠧ Preparing packages... (66/68)
# ⠧ Preparing packages... (66/68)
# ⠇ Preparing packages... (66/68)
# ⠇ Preparing packages... (66/68)
# ⠇ Preparing packages... (66/68)
# ⠇ Preparing packages... (66/68)
# ⠋ Preparing packages... (66/68)
# ⠋ Preparing packages... (66/68)
# ⠋ Preparing packages... (66/68)
# ⠋ Preparing packages... (66/68)
# ⠙ Preparing packages... (66/68)
# ⠙ Preparing packages... (66/68)
# ⠙ Preparing packages... (66/68)
# ⠙ Preparing packages... (66/68)
# ⠹ Preparing packages... (66/68)
# ⠹ Preparing packages... (66/68)
# ⠹ Preparing packages... (66/68)
# ⠹ Preparing packages... (66/68)
# ⠸ Preparing packages... (66/68)
# ⠸ Preparing packages... (66/68)
# Prepared 68 packages in 31.62s
# Installed 68 packages in 373ms
#  + annotated-types==0.7.0
#  + anyio==4.4.0
#  + certifi==2024.2.2
#  + charset-normalizer==3.3.2
#  + contourpy==1.2.1
#  + cycler==0.12.1
#  + distro==1.9.0
#  + exceptiongroup==1.2.1
#  + filelock==3.14.0
#  + fonttools==4.52.4
#  + fsspec==2024.5.0
#  + h11==0.14.0
#  + httpcore==1.0.5
#  + httpx==0.27.0
#  + huggingface-hub==0.23.2
#  + idna==3.7
#  + jinja2==3.1.4
#  + joblib==1.4.2
#  + kiwisolver==1.4.5
#  + markdown-it-py==3.0.0
#  + markupsafe==2.1.5
#  + matplotlib==3.9.0
#  + mdurl==0.1.2
#  + mpmath==1.3.0
#  + networkx==3.3
#  + numpy==1.26.4
#  + nvidia-cublas-cu12==12.1.3.1
#  + nvidia-cuda-cupti-cu12==12.1.105
#  + nvidia-cuda-nvrtc-cu12==12.1.105
#  + nvidia-cuda-runtime-cu12==12.1.105
#  + nvidia-cudnn-cu12==8.9.2.26
#  + nvidia-cufft-cu12==11.0.2.54
#  + nvidia-curand-cu12==10.3.2.106
#  + nvidia-cusolver-cu12==11.4.5.107
#  + nvidia-cusparse-cu12==12.1.0.106
#  + nvidia-nccl-cu12==2.19.3
#  + nvidia-nvjitlink-cu12==12.6.77
#  + nvidia-nvtx-cu12==12.1.105
#  + openai==1.19.0
#  + packaging==24.0
#  + pandas==2.2.2
#  + pillow==10.3.0
#  + pydantic==2.7.2
#  + pydantic-core==2.18.3
#  + pygments==2.18.0
#  + pyparsing==3.1.2
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.0.1
#  + pytz==2024.1
#  + pyyaml==6.0.1
#  + regex==2024.5.15
#  + requests==2.32.3
#  + rich==13.7.1
#  + safetensors==0.4.3
#  + scikit-learn==1.4.2
#  + scipy==1.13.1
#  + six==1.16.0
#  + sniffio==1.3.1
#  + sympy==1.12.1
#  + threadpoolctl==3.5.0
#  + tokenizers==0.19.1
#  + torch==2.2.1
#  + tqdm==4.66.4
#  + transformers==4.43.1
#  + triton==2.2.0
#  + typing-extensions==4.12.0
#  + tzdata==2024.1
#  + urllib3==2.2.1

# %%
# !echo "OPENAI_API_KEY=your_openai_key" > .env
# %load_ext dotenv
# %dotenv

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import re
import time
import json
import pandas as pd
import numpy as np
import asyncio

import openai
from openai import OpenAI

from asyncio import Semaphore
from tqdm.asyncio import tqdm

import warnings
warnings.simplefilter("ignore")

from attribution.api_attribution import OpenAIAttributor
from attribution.experiment_logger import ExperimentLogger
from attribution.token_perturbation import (
    FixedPerturbationStrategy,
    NthNearestPerturbationStrategy,
)
# Out:
# Mounted at /content/drive
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]

# %% [markdown]
# # Define code

# %%
PROMPT_TEMPLATE_VERDICT = """
You are presented with a MODEL_ANSWER by an LLM.

Identify whether the MODEL_ANSWER is a Refusal or is Okay.

- **Refusal:** Indicates an inability to provide an answer, acknowledges a lack of response, expresses doubt, or uncertainty.
- **Okay:** Does not meet the criteria for a Refusal.

Provide your analysis and ensure that the last line of your RESPONSE is:

VERDICT: $VERDICT

where $VERDICT is either "Refusal" or "Okay".

MODEL_ANSWER: {Model_answer}

RESPONSE:
""".strip()

# %%
import os
import json
import asyncio
import time

# from evaluate import load
import evaluate
import logging
import ast
import hashlib

# %%
# CELL 1

from tenacity import retry, wait_random_exponential, retry_if_not_exception_type

from openai import OpenAI

CLIENT = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

class OpenAIKeyError(Exception):
    """OpenAI API key not provided in environment variable."""
    pass

@retry(retry=retry_if_not_exception_type(OpenAIKeyError), wait=wait_random_exponential(min=1, max=10))
def predict(prompt, temperature=1.0, model='gpt-4o'):
    """Predict with GPT models."""

    if not CLIENT.api_key:
        raise OpenAIKeyError('Need to provide OpenAI API key in environment variable `OPENAI_API_KEY`.')

    if isinstance(prompt, str):
        messages = [{'role': 'user', 'content': prompt}]
    else:
        messages = prompt

    model_mapping = {
        'gpt-4': 'gpt-4-0613',
        'gpt-4-turbo': 'gpt-4-1106-preview',
        'gpt-3.5': 'gpt-3.5-turbo-1106',
        'gpt-4o': 'gpt-4o-2024-05-13'
    }
    model = model_mapping.get(model, model)

    output = CLIENT.chat.completions.create(
        model=model,
        messages=messages,
        max_tokens=200,
        temperature=temperature,
    )
    response = output.choices[0].message.content
    return response

def md5hash(string):
    """Generate MD5 hash for a given string."""
    return int(hashlib.md5(string.encode('utf-8')).hexdigest(), 16)

# %%
# CELL 2

def model_based_metric(predicted_answer, example, model_name='gpt-4o'):
    """Assess the quality of the predicted answer using a model-based metric."""
    if 'answers' in example:
        correct_answers = example['answers']['text']
    elif 'reference' in example:
        correct_answers = example['reference']['answers']['text']
    else:
        raise ValueError("Example must contain 'answers' or 'reference' with 'answers'.")

    prompt = f"We are assessing the quality of answers to the following question: {example['question']}\n"
    if len(correct_answers) == 1:
        prompt += f"The expected answer is: {correct_answers[0]}.\n"
    else:
        prompt += f"The following are expected answers to this question: {correct_answers}.\n"

    prompt += f"The proposed answer is: {predicted_answer}\n"

    if len(correct_answers) == 1:
        prompt += "Within the context of the question, does the proposed answer mean the same as the expected answer?"
    else:
        prompt += "Within the context of the question, does the proposed answer mean the same as any of the expected answers?"

    prompt += " Respond only with yes or no.\nResponse:"

    response = predict(prompt, model=model_name)
    response_lower = response.strip().lower()

    if 'yes' in response_lower:
        return 1.0
    elif 'no' in response_lower:
        return 0.0
    else:
        logging.warning('Ambiguous response received. Retrying LLM check.')
        response = predict(prompt, model=model_name)
        response_lower = response.strip().lower()
        if 'yes' in response_lower:
            return 1.0
        elif 'no' in response_lower:
            return 0.0
        logging.warning('Unable to determine yes or no from response. Defaulting to 0.0.')
        return 0.0

def llm_metric(predicted_answer, example):
    """LLM-based metric without specifying model."""
    return model_based_metric(predicted_answer, example)

def get_gpt_metric(model_name='gpt-4o'):
    """Get GPT-based metric function with specified model."""

    def gpt_metric(predicted_answer, example):
        return model_based_metric(predicted_answer, example, model_name=model_name)

    return gpt_metric

def get_reference(example):
    """Extract reference answers from the example."""
    if 'answers' not in example:
        example = example['reference']
    answers = example['answers']
    answer_starts = answers.get('answer_start', [])
    reference = {'answers': {'answer_start': answer_starts, 'text': answers['text']}, 'id': example['id']}
    logging.debug(f"Reference extracted: {reference}")
    return reference

def get_metric(metric_name):
    """Retrieve the appropriate metric function based on the metric name."""
    print('we got here 1')
    if metric_name == 'squad':
        print('we got here 1.5')
        squad_metric = evaluate.load('C:/Users/juanv/Documents/arb/pizza/evaluate/metrics/squad_v2/squad_v2.py')  # Corrected line

        def squad_metric_fn(response, example, *args, **kwargs):
            print('we got here 2')
            if 'id' in example:
                exid = example['id']
            elif 'id' in example['reference']:
                exid = example['reference']['id']
            else:
                raise ValueError

            pred = {'prediction_text': response, 'no_answer_probability': 0.0, 'id': exid}
            print('we got here 3')
            results = squad_metric.compute(
                predictions=[pred],
                references=[get_reference(example)]
            )
            print('we got here 4')
            return 1.0 if (results['f1'] >= 50.0) else 0.0

        return squad_metric_fn

    elif metric_name == 'llm':
        return llm_metric
    elif metric_name == 'llm_gpt-3.5':
        return get_gpt_metric(model_name='gpt-3.5')
    elif metric_name == 'llm_gpt-4':
        return get_gpt_metric(model_name='gpt-4o')
    else:
        raise ValueError(f"Unknown metric: {metric_name}")

# %%
# CELL 3
import asyncio
import json
import os
import re
import logging
from asyncio import Semaphore
from tqdm import tqdm
import ast
from tqdm.asyncio import tqdm


def split_array(arr):
    """Split array items containing newline into tokens and attribution values."""
    tokens = []
    att_values = []

    for item in arr:
        if '\n' in str(item):
            parts = str(item).split('\n')
            tokens.append(parts[0].strip())
            att_values.append(float(parts[1]))
        else:
            tokens.append(str(item).strip())
            att_values.append(None)

    return tokens, att_values

async def get_total_attribution(prompt, max_retries=3):
    logger = ExperimentLogger()

    for attempt in range(max_retries):
        try:
            logging.info(f"Attempt {attempt + 1} for get_total_attribution.")
            await attributor.hierarchical_perturbation(
                prompt,
                logger=logger,
                attribution_strategies=["cosine", "prob_diff"],
                perturbation_strategy=FixedPerturbationStrategy(replacement_token=""),
                max_depth=1,
            )

            output = logger.df_experiments['original_output'].iloc[-1]
            total_att = logger.print_total_attribution(exp_id=-1)

            try:
                mat_full = logger.get_attribution_matrices(exp_id=-1)
            except ValueError as e:
                logging.error(f"Error getting attribution matrices: {str(e)}")
                mat_full = None

            tokens, cosine_vals = split_array(total_att.values[0][4:])
            _, prob_diff_vals = split_array(total_att.values[1][4:])

            if output is None or output.strip() == "":
                raise ValueError("Output is None or empty")

            if any(x is None or (isinstance(x, (list, np.ndarray)) and len(x) == 0) for x in [cosine_vals, prob_diff_vals, tokens, mat_full]):
                raise ValueError("One or more results are None or empty")

            return cosine_vals, prob_diff_vals, tokens, output, mat_full

        except Exception as e:
            logging.error(f"Attempt {attempt + 1} failed in get_total_attribution: {str(e)}", exc_info=True)
            if attempt < max_retries - 1:
                sleep_time = 2 ** attempt  # Exponential backoff
                logging.info(f"Retrying in {sleep_time} seconds...")
                await asyncio.sleep(sleep_time)
            else:
                logging.error("Max retries reached in get_total_attribution. Returning None values.")
                return None, None, None, None, None

async def get_refusal_verdict(output):
    system_message = "You are a helpful assistant."
    model = "gpt-4o"
    temperature = 0.7
    top_p = 1
    max_tokens = 800
    message_list = [{"role": "user", "content": PROMPT_TEMPLATE_VERDICT.format(Model_answer=output)}]
    message_list = [{"role": "system", "content": system_message}] + message_list

    trial = 0
    while True:
        try:
            response = await asyncio.to_thread(
                CLIENT.chat.completions.create,
                model=model,
                messages=message_list,
                temperature=temperature,
                top_p=top_p,
                max_tokens=max_tokens,
            )
            res = response.choices[0].message.content

            ANSWER_PATTERN = r"(?i)VERDICT\s*:\s*(.*?)(?:\n|$)"
            match = re.search(ANSWER_PATTERN, res)

            if match:
                verdict = match.group(1).strip()
                return res, verdict
            else:
                logging.warning("Response format invalid. 'VERDICT' not found.")
                return res, None
        except Exception as e:
            exception_backoff = 2 ** trial  # Exponential backoff
            logging.error(f"Exception in get_refusal_verdict, attempt {trial + 1}. Retrying after {exception_backoff} seconds.", exc_info=True)
            await asyncio.sleep(exception_backoff)
            trial += 1
            if trial > 5:  # Max 5 retries
                logging.error("Max retries reached in get_refusal_verdict. Skipping this request.")
                return None, None

async def get_hallucination_verdict(output, example, metric_arg):
    metric = get_metric(metric_arg)
    is_correct = metric(output, example)
    logging.debug(f"Metric result (is_correct): {is_correct}")

    if is_correct == 1.0:
        verdict = 'Correct'
        return verdict
    else:
        res, verdict = await get_refusal_verdict(output)
        logging.debug(f"Refusal verdict: {verdict}")
        if verdict:
            verdict_lower = verdict.lower()
            if 'refusal' in verdict_lower:
                return 'Refusal'
            elif 'okay' in verdict_lower:
                return 'Hallucination'
        return 'Unknown'


async def process_row(idx, id, question, context, answer, metric_arg, max_retries=5):
    for attempt in range(max_retries):
        try:
            example = {
                "id": id,
                "question": question,
                "context": context,
                "answers": ast.literal_eval(answer)
            }

            question_nature_format = f"""{question} Give a complete single brief answer."""

            cosine_vals, prob_diff_vals, tokens, output, mats_full = await get_total_attribution(question_nature_format)

            if output is None:
                print(f">>> {idx} has no OUTPUT")
            print(f">>> {idx} OUTPUT: {output}")
            print(f">>> {idx} VALS: {cosine_vals}")
            verdict = await get_hallucination_verdict(output, example, metric_arg)

            print(f">>> {idx} VERDICT: {verdict}")

            if mats_full is not None:
                mats_json_data = []
                for i, df in enumerate(mats_full):
                    mats_json_data.append({
                        "matrix_id": i,
                        "data": df.reset_index().to_dict(orient="records")
                    })
            else:
                mats_json_data = None

            # print(f">>>>Row {idx}<<<<")
            # print(f"Input: {question}")
            # print(f"Output: {output}")
            # print(f"Correct Answer: {answer}")
            # print(f"Verdict: {verdict}")
            # print(f"Tokens: {tokens}")
            # print(f"Cosine values: {cosine_vals}")
            # print(f"ProbDiff values: {prob_diff_vals}")
            # print(f"Mat full: {mats_json_data}")

            result = {
                "row": idx,
                "id": id,
                "input": question,
                "output": output,
                "correct_answer": answer,
                "verdict": verdict,
                "tokens": tokens,
                "cosine_values": cosine_vals,
                "prob_diff_values": prob_diff_vals,
                "attributions_full": mats_json_data,
                "context": context
            }

            success = await save_result_with_retry(results_dir, idx, result)
            if success:
                print(f"Saved result for row Y{idx+1} to JSON file")
                return
            else:
                print(f"Failed to save result for row Y{idx+1} after multiple attempts.")

        except Exception as e:
            print(f"Error processing row {idx}, attempt {attempt + 1}: {str(e)}")
            if attempt == max_retries - 1:
                print(f"Max retries reached for row {idx}. Saving partial data.")
                result = {
                    "row": idx,
                    "id": id,
                    "input": question,
                    "output": str(e),
                    "correct_answer": answer,
                    "verdict": None,
                    "tokens": None,
                    "cosine_values": None,
                    "prob_diff_values": None,
                    "attributions_full": None,
                    "context": context
                }
                await save_result_with_retry(results_dir, idx, result, file_suffix="_error")
            else:
                await asyncio.sleep(1)

async def save_result_with_retry(results_dir, idx, result, max_attempts=10, delay=3, file_suffix=""):
    for attempt in range(max_attempts):
        try:
            file_path = os.path.join(results_dir, f"new_result_{idx}{file_suffix}.json")
            with open(file_path, 'w') as f:
                json.dump(result, f, indent=2)
            return True
        except IOError as e:
            logging.error(f"Attempt {attempt + 1} failed: Error saving result for row {idx}. Error: {str(e)}")
            if attempt < max_attempts - 1:
                logging.info(f"Retrying save in {delay} seconds...")
                await asyncio.sleep(delay)
    logging.error(f"Failed to save result for row {idx} after {max_attempts} attempts.")
    return False

async def process_rows(df_array, metric_arg, max_concurrent=24):
    semaphore = Semaphore(max_concurrent)
    total_rows = len(df_array)

    async def worker(idx, id, question, context, answer):
        async with semaphore:
            await process_row(idx, id, question, context, answer, metric_arg)

    tasks = []
    for idx, id, context, question, answer in df_array:
        task = asyncio.create_task(worker(idx, id, question, context, answer))
        tasks.append(task)

    for task in tqdm.as_completed(tasks, total=total_rows, desc="Processing rows"):
        try:
            await task
        except Exception as e:
            print(f"Unhandled error in task: {str(e)}")

# %% [markdown]
# # Run code

# %%
base_dir = 'your_base_dir'

data_folder = 'your_data_folder'
output_folder = 'output'

name_of_output = 'train_sample' # choose appropriate name

data_dir = os.path.join(base_dir, data_folder)
output_dir = os.path.join(base_dir, output_folder)
os.makedirs(output_dir, exist_ok=True)

# %%
# testing
print(os.listdir(data_dir))
# Out:
# ['squad_test_set_3000.csv', 'nq_train_set_3000.csv', 'squad_train_set_3000.csv', 'nq_test_set_3000.csv', 'squad', 'nq', 'squad_train_set_10000.csv', 'squad10k', 'nq_train_set_10000.csv', 'nq10k', 'squad_10k_train_processed.csv', 'nq_10k_train_processed.csv', 'final_datasets']

# %%
df = pd.read_csv(os.path.join(data_dir, 'squad_train_set_10000.csv'))
df.drop(columns=['title'], inplace=True)

# %%
df.head(3)
# Out:
#                          id  \
# 0  57101271b654c5140001f7b7
# 1  5726684d708984140094c509
# 2  56f8b1989b226e1400dd0e29
#
#                                              context  \
# 0  Congress acted defiantly toward the Supreme Co...
# 1  Bonaparte could win battles by concealment of ...
# 2  Additionally, genes can have regulatory region...
#
#                                             question  \
# 0  Under the Drug Kingpin Act of 1988 and Federal...
# 1  How many standards did Napoleon's army capture...
# 2           How do enhancers increase transcription?
#
#                                              answers
# 0         {'text': ['fifty'], 'answer_start': [150]}
# 1           {'text': ['170'], 'answer_start': [443]}
# 2  {'text': ['by binding an activator protein'], ...

# %%
# for fn in os.listdir(data_dir):
#     if fn.endswith('.csv'):
#         df = pd.read_csv(os.path.join(data_dir, fn))
#         print(f">> df for {fn}")
#         display(df.head(3))

# %%
attributor = OpenAIAttributor(openai_model='gpt-4o-mini')
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
metric_arg = 'llm_gpt-4' # for squad, it's squad
results_dir = os.path.join(output_dir, name_of_output)
os.makedirs(results_dir, exist_ok=True)
df_testing = df.reset_index().values

# %%
print(f"> Num of samples is {len(df_testing)}.\n> First 3 samples:")
print(df_testing[:3])
# Out:
# > Num of samples is 10000.
# > First 3 samples:
# [[0 '57101271b654c5140001f7b7'
#   'Congress acted defiantly toward the Supreme Court by passing the Drug Kingpin Act of 1988 and the Federal Death Penalty Act of 1994 that made roughly fifty crimes punishable by death, including crimes that do not always involve the death of someone. Such non-death capital offenses include treason, espionage (spying for another country), and high-level drug trafficking. Since no one has yet been sentenced to death for such non-death capital offenses, the Supreme Court has not ruled on their constitutionality.'
#   'Under the Drug Kingpin Act of 1988 and Federal Death Penalty Act of 1994, about how many crimes were punishable by death?'
#   "{'text': ['fifty'], 'answer_start': [150]}"]
#  [1 '5726684d708984140094c509'
#   "Bonaparte could win battles by concealment of troop deployments and concentration of his forces on the 'hinge' of an enemy's weakened front. If he could not use his favourite envelopment strategy, he would take up the central position and attack two co-operating forces at their hinge, swing round to fight one until it fled, then turn to face the other. In this Italian campaign, Bonaparte's army captured 150,000 prisoners, 540 cannons, and 170 standards. The French army fought 67 actions and won 18 pitched battles through superior artillery technology and Bonaparte's tactics."
#   "How many standards did Napoleon's army capture in the Italian campaign?"
#   "{'text': ['170'], 'answer_start': [443]}"]
#  [2 '56f8b1989b226e1400dd0e29'
#   'Additionally, genes can have regulatory regions many kilobases upstream or downstream of the open reading frame. These act by binding to transcription factors which then cause the DNA to loop so that the regulatory sequence (and bound transcription factor) become close to the RNA polymerase binding site. For example, enhancers increase transcription by binding an activator protein which then helps to recruit the RNA polymerase to the promoter; conversely silencers bind repressor proteins and make the DNA less available for RNA polymerase.'
#   'How do enhancers increase transcription?'
#   "{'text': ['by binding an activator protein'], 'answer_start': [352]}"]]

# %%
print(results_dir)
# Out:
# /content/drive/MyDrive/arb/pizza/pizza-dataset-files/nature_datasets_FINAL/squad10k/train_sample

# %%
await process_rows(df_testing[0:10], metric_arg)

# %% [markdown]
# # Squad datasets

# %%
# df = pd.read_csv(os.path.join(data_dir, 'squad_test_set_XXXX.csv')) # use the right file
# df.drop(columns=['title'], inplace=True)
# results_dir = os.path.join(output_dir, 'squad','train_v1_llm_sample')
# os.makedirs(results_dir, exist_ok=True)
# df_array_TRAIN = df.reset_index().values

# %%
# await process_rows(df_array_TRAIN, metric_arg)

# %%
# df = pd.read_csv(os.path.join(data_dir, 'squad_test_set_XXXX.csv')) # use the right file
# df.drop(columns=['title'], inplace=True)
# results_dir = os.path.join(output_dir, 'squad','test_v1_llm_sample')
# os.makedirs(results_dir, exist_ok=True)
# df_array_TEST = df.reset_index().values

# %%
# await process_rows(df_array_TEST, metric_arg)

# %% [markdown]
# # Process dir

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import re
import time
import json
import pandas as pd
import numpy as np
import asyncio


def read_json_file(file_path):
    try:
        with open(file_path, 'r') as f:
            return json.load(f)
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
        return None

def custom_progress_bar(iterable, desc="Processing", total=None):
    if total is None:
        total = len(iterable)

    print(f"{desc}:")
    progress_interval = max(1, total // 20)  # 5% intervals
    for i, item in enumerate(iterable, 1):
        yield item
        if i % progress_interval == 0 or i == total:
            progress = (i / total) * 100
            print(f"Progress: {progress:.1f}% ({i}/{total})")

def process_directory(results_dir):
    json_files = [os.path.join(results_dir, fn) for fn in os.listdir(results_dir) if fn.endswith('.json')]

    data = [file_data for file in custom_progress_bar(json_files, desc="Reading JSON files", total=len(json_files))
            if (file_data := read_json_file(file)) is not None]

    return pd.DataFrame(data)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = os.path.join(base_dir, data_folder)
output_dir = os.path.join(base_dir, output_folder)
os.makedirs(output_dir, exist_ok=True)

# %%
df = process_directory(results_dir)
# Out:
# Reading JSON files:
# Progress: 10.0% (1/10)
# Progress: 20.0% (2/10)
# Progress: 30.0% (3/10)
# Progress: 40.0% (4/10)
# Progress: 50.0% (5/10)
# Progress: 60.0% (6/10)
# Progress: 70.0% (7/10)
# Progress: 80.0% (8/10)
# Progress: 90.0% (9/10)
# Progress: 100.0% (10/10)

# %%
df.head(1)
# Out:
#    row                        id  \
# 0    6  56ce35b2aab44d1400b885b4
#
#                                                input  \
# 0  What ailment did Harper Lee's mother suffer from?
#
#                                               output  \
# 0  Harper Lee's mother suffered from mental illne...
#
#                                       correct_answer  verdict  \
# 0  {'text': ['mental illness'], 'answer_start': [...  Correct
#
#                                               tokens  \
# 0  [What, ail, ment, did, Harper, Lee, 's, mother...
#
#                                        cosine_values  \
# 0  [0.05, 0.05, 0.07, 0.07, 0.09, 0.08, 0.08, 0.0...
#
#                                     prob_diff_values  \
# 0  [0.08, 0.08, 0.1, 0.1, 0.13, 0.11, 0.11, 0.11,...
#
#                                    attributions_full  \
# 0  [{'matrix_id': 0, 'data': [{'index': 'What (0)...
#
#                                              context
# 0  Lee had lost her mother, who suffered from men...

# %%
df.to_csv(os.path.join(results_dir,f'{name_of_output}.csv'), index=False) # use appropriate name
